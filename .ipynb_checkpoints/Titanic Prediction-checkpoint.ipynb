# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

# %%
train = pd.read_csv("/Users/raghavagovil/Desktop/Titanic Prediciton/Titanic Data/train.csv")
test = pd.read_csv("/Users/raghavagovil/Desktop/Titanic Prediciton/Titanic Data/test.csv")
combine = [train, test]

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
len(train[train['Sex'] == "male"])
# Out:
# 577

# %%
train.describe(include=['O'])
# Out:
#                             Name   Sex  Ticket        Cabin Embarked
# count                        891   891     891          204      889
# unique                       891     2     681          147        3
# top     Mudd, Mr. Thomas Charles  male  347082  C23 C25 C27        S
# freq                           1   577       7            4      644

# %%
train[['Survived', 'Pclass']].groupby(['Pclass'], as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
train[['Survived', 'Sex']].groupby(['Sex'], as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
train[['Survived', 'Parch']].groupby(['Parch'], as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %%
train[['Survived', 'SibSp']].groupby(['SibSp'], as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
g = sns.FacetGrid(train, col = 'Survived')
g.map(plt.hist, 'Age', bins = 20, edgecolor = 'black')

# %%
grid = sns.FacetGrid(train, col = 'Survived', row = 'Pclass', size = 2.2, aspect = 1.6)
grid.map(plt.hist, 'Age', bins = 20, edgecolor = 'black', alpha = 0.5)
grid.add_legend()

# %%
grid = sns.FacetGrid(train, row = 'Embarked', size = 2.2, aspect = 1.6)
grid.map(sns.pointplot, 'Pclass', 'Survived', 'Sex', palette = 'deep')
grid.add_legend()
# Out:
# /anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:708: UserWarning: Using the pointplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
grid = sns.FacetGrid(train, col = 'Survived', row = 'Embarked', size = 2.2, aspect = 1.6)
grid.map(sns.barplot, 'Sex', 'Fare', alpha = 0.5, ci = None)
grid.add_legend()
# Out:
# /anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
train = train.drop(['Ticket', 'Cabin'], axis=1)
test = test.drop(['Ticket', 'Cabin'], axis=1)
combine = [train, test]

# %%
for dataset in combine:
    dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

pd.crosstab(train['Title'], train['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
for dataset in combine:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col','Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')

train[['Title', 'Survived']].groupby(['Title'], as_index = False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4    Rare  0.347826

# %%
title_mapping = {'Mr':1, 'Miss':2, 'Mrs':3, 'Master':4, 'Rare': 5}
for dataset in combine:
    dataset['Title'] = dataset['Title'].map(title_mapping)
    dataset['Title'] = dataset['Title'].fillna(0)

train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked  Title
# 0      0   7.2500        S      1
# 1      0  71.2833        C      3
# 2      0   7.9250        S      2
# 3      0  53.1000        S      3
# 4      0   8.0500        S      1

# %%
train = train.drop(['Name', 'PassengerId'], axis=1)
test = test.drop(['Name'], axis=1)
combine = [train, test]
train.shape, test.shape
# Out:
# ((891, 9), (418, 9))

# %%
for dataset in combine:
    dataset['Sex'] = dataset['Sex'].map({'female':1, 'male':0}).astype(int)

train.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    0  22.0      1      0   7.2500        S      1
# 1         1       1    1  38.0      1      0  71.2833        C      3
# 2         1       3    1  26.0      0      0   7.9250        S      2
# 3         1       1    1  35.0      1      0  53.1000        S      3
# 4         0       3    0  35.0      0      0   8.0500        S      1

# %%
guess_age = np.zeros((2,3))
guess_age
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
for dataset in combine:
    for i in range(0,2):
        for j in range(0,3):
            guess_df = dataset[(dataset['Sex']==i) & (dataset['Pclass']==j+1)]['Age'].dropna()
            age_fill = guess_df.median()
            guess_age[i,j] = int(age_fill/0.5 + 0.5)*0.5
    
    for i in range(0,2):
        for j in range(0,3):
            dataset.loc[(dataset.Age.isnull())&(dataset.Sex==i)&(dataset.Pclass == j+1), 'Age'] = guess_age[i,j]
    
    dataset['Age'] = dataset['Age'].astype(int)

train.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    0   22      1      0   7.2500        S      1
# 1         1       1    1   38      1      0  71.2833        C      3
# 2         1       3    1   26      0      0   7.9250        S      2
# 3         1       1    1   35      1      0  53.1000        S      3
# 4         0       3    0   35      0      0   8.0500        S      1

# %%
train['AgeBand'] = pd.cut(train['Age'], 5)
train[['AgeBand', 'Survived']].groupby(['AgeBand'], as_index = False).mean().sort_values(by='AgeBand', ascending = True)
# Out:
#          AgeBand  Survived
# 0  (-0.08, 16.0]  0.550000
# 1   (16.0, 32.0]  0.337374
# 2   (32.0, 48.0]  0.412037
# 3   (48.0, 64.0]  0.434783
# 4   (64.0, 80.0]  0.090909

# %%
for dataset in combine:    
    dataset.loc[ dataset['Age'] <= 16, 'Age'] = 0
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 32), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 32) & (dataset['Age'] <= 48), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 48) & (dataset['Age'] <= 64), 'Age'] = 3
    dataset.loc[ dataset['Age'] > 64, 'Age']
train.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare Embarked  Title  \
# 0         0       3    0    1      1      0   7.2500        S      1
# 1         1       1    1    2      1      0  71.2833        C      3
# 2         1       3    1    1      0      0   7.9250        S      2
# 3         1       1    1    2      1      0  53.1000        S      3
# 4         0       3    0    2      0      0   8.0500        S      1
#
#         AgeBand
# 0  (16.0, 32.0]
# 1  (32.0, 48.0]
# 2  (16.0, 32.0]
# 3  (32.0, 48.0]
# 4  (32.0, 48.0]

# %%
train = train.drop(['AgeBand'], axis = 1)
combine = [train, test]
train.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    0    1      1      0   7.2500        S      1
# 1         1       1    1    2      1      0  71.2833        C      3
# 2         1       3    1    1      0      0   7.9250        S      2
# 3         1       1    1    2      1      0  53.1000        S      3
# 4         0       3    0    2      0      0   8.0500        S      1

# %%
for dataset in combine:
    dataset['Fam'] = dataset['SibSp'] + dataset['Parch'] + 1

train[['Fam', 'Survived']].groupby(['Fam'], as_index = False).mean().sort_values(by = 'Fam', ascending = True)
# Out:
#    Fam  Survived
# 0    1  0.303538
# 1    2  0.552795
# 2    3  0.578431
# 3    4  0.724138
# 4    5  0.200000
# 5    6  0.136364
# 6    7  0.333333
# 7    8  0.000000
# 8   11  0.000000

# %%
for dataset in combine:
    dataset['Alone'] = 0
    dataset.loc[(dataset['Fam']==1), 'Alone'] = 1

train[['Alone', 'Survived']].groupby(['Alone'], as_index = False).mean().sort_values(by = 'Alone', ascending = True)
# Out:
#    Alone  Survived
# 0      0  0.505650
# 1      1  0.303538

# %%
train = train.drop(['Parch', 'SibSp', 'Fam'], axis=1)
test = test.drop(['Parch', 'SibSp', 'Fam'], axis=1)
combine = [train, test]

train.head()
# Out:
#    Survived  Pclass  Sex  Age     Fare Embarked  Title  Alone
# 0         0       3    0    1   7.2500        S      1      0
# 1         1       1    1    2  71.2833        C      3      0
# 2         1       3    1    1   7.9250        S      2      1
# 3         1       1    1    2  53.1000        S      3      0
# 4         0       3    0    2   8.0500        S      1      1

# %%
for dataset in combine:
    dataset['Age*Class'] = dataset['Age'] * dataset['Pclass']

train[['Age*Class', 'Age', 'Pclass']].head()
# Out:
#    Age*Class  Age  Pclass
# 0          3    1       3
# 1          2    2       1
# 2          3    1       3
# 3          2    2       1
# 4          6    2       3

# %%
fr_emb = train.Embarked.dropna().mode()[0]
fr_emb
# Out:
# 'S'

# %%
train['Embarked'] = train['Embarked'].fillna(fr_emb)
test['Embarked'] = test['Embarked'].fillna(fr_emb)
combine = [train, test]

# %%
train[['Embarked', 'Survived']].groupby(['Embarked'], as_index = False).mean().sort_values(by = 'Embarked', ascending = True)
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.339009

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
# Survived     891 non-null int64
# Pclass       891 non-null int64
# Sex          891 non-null int64
# Age          891 non-null int64
# Fare         891 non-null float64
# Embarked     891 non-null object
# Title        891 non-null int64
# Alone        891 non-null int64
# Age*Class    891 non-null int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 62.7+ KB

# %%
train['Embarked'] = train['Embarked'].map({'S':0, 'C':1, 'Q':2}).astype(int)
test['Embarked'] = test['Embarked'].map({'S':0, 'C':1, 'Q':2}).astype(int)
combine = [train, test]
train.head()
# Out:
#    Survived  Pclass  Sex  Age     Fare  Embarked  Title  Alone  Age*Class
# 0         0       3    0    1   7.2500         0      1      0          3
# 1         1       1    1    2  71.2833         1      3      0          2
# 2         1       3    1    1   7.9250         0      2      1          3
# 3         1       1    1    2  53.1000         0      3      0          2
# 4         0       3    0    2   8.0500         0      1      1          6

# %%
test['Fare'].fillna(test['Fare'].dropna().median(), inplace = True)
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Sex            418 non-null int64
# Age            418 non-null int64
# Fare           418 non-null float64
# Embarked       418 non-null int64
# Title          418 non-null int64
# Alone          418 non-null int64
# Age*Class      418 non-null int64
# dtypes: float64(1), int64(8)
# memory usage: 29.5 KB

# %%
train['FareSplit'] = pd.qcut(train['Fare'], 4)
train[['FareSplit', 'Survived']].groupby(['FareSplit'], as_index = False).mean().sort_values(by='FareSplit', ascending = True)
# Out:
#          FareSplit  Survived
# 0   (-0.001, 7.91]  0.197309
# 1   (7.91, 14.454]  0.303571
# 2   (14.454, 31.0]  0.454955
# 3  (31.0, 512.329]  0.581081

# %%
for dataset in combine:
    dataset.loc[dataset['Fare'] <= 7.91, 'Fare'] = 0
    dataset.loc[(dataset['Fare'] > 7.91) & (dataset['Fare'] <= 14.454), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 14.454) & (dataset['Fare'] <= 31), 'Fare']   = 2
    dataset.loc[ dataset['Fare'] > 31, 'Fare'] = 3
    dataset['Fare'] = dataset['Fare'].astype(int)

train = train.drop(['FareSplit'], axis = 1)
train.head()
combine = [train, test]

# %%
x_train = train.drop(['Survived'], axis = 1)
y_train = train['Survived']
x_test = test.drop(['PassengerId'], axis = 1).copy()

# %%
log_reg = LogisticRegression()
log_fit = log_reg.fit(x_train, y_train)
y_pred = log_reg.predict(x_test)
log_reg_score = log_reg.score(x_train, y_train) * 100
log_reg_score
# Out:
# 80.3591470258137

# %%
coeff = pd.DataFrame(train.columns.delete(0))
coeff.columns = ['Feature']
coeff['Correlation'] = pd.Series(log_reg.coef_[0])
coeff.sort_values(by = 'Correlation', ascending = False)
# Out:
#      Feature  Correlation
# 1        Sex     2.201527
# 5      Title     0.398234
# 2        Age     0.287166
# 4   Embarked     0.261762
# 6      Alone     0.129141
# 3       Fare    -0.085150
# 7  Age*Class    -0.311198
# 0     Pclass    -0.749006

# %%
svm = SVC()
svm_fit = svm.fit(x_train, y_train)
y_pred = svm.predict(x_test)
svm_score = svm.score(x_train, y_train) * 100
svm_score
# Out:
# 83.83838383838383

# %%
knn = KNeighborsClassifier()
knn_fit = knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
knn_score = knn.score(x_train, y_train) * 100
knn_score
# Out:
# 83.9506172839506

# %%
gauss = GaussianNB()
gauss_fit = gauss.fit(x_train, y_train)
y_pred = gauss.predict(x_test)
gauss_score = gauss.score(x_train, y_train) * 100
gauss_score
# Out:
# 72.27833894500561

# %%
dec_tree = DecisionTreeClassifier()
dec_tree_fit = dec_tree.fit(x_train, y_train)
y_pred = dec_tree.predict(x_test)
dec_tree_score = dec_tree.score(x_train, y_train) * 100
dec_tree_score
# Out:
# 86.75645342312009

# %%
rf = RandomForestClassifier(n_estimators=100)
rf_fit = rf.fit(x_train, y_train)
y_pred = rf.predict(x_test)
rf_score = rf.score(x_train, y_train) * 100
rf_score
# Out:
# 86.75645342312009

# %%
models = pd.DataFrame({
    'Model': ['Logistic Regression', 'Support Vector Machine', 'KNN', 'Gaussian Naive Bayes', 'Decision Tree', 'Random Forrest'],
    'Score': [log_reg_score, svm_score, knn_score, gauss_score, dec_tree_score, rf_score]
})
models.sort_values(by = 'Score', ascending = False)
# Out:
#                     Model      Score
# 4           Decision Tree  86.756453
# 5          Random Forrest  86.756453
# 2                     KNN  83.950617
# 1  Support Vector Machine  83.838384
# 0     Logistic Regression  80.359147
# 3    Gaussian Naive Bayes  72.278339

# %%
final = pd.DataFrame({
    'PassengerId': test['PassengerId'],
    'Survived': y_pred
})
#final.to_csv(r'/Users/raghavagovil/Desktop/Titanic Prediciton/final.csv')
